# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap as Basemap
import matplotlib.lines as mlines

# %%
pd.set_option("max_rows", 5)
pd.set_option("max_columns", None)

# %%
# '역' & '(###)'지우기
def stationNameClear(stations):
    station_list = []
    for station in stations['역사명']:
        if station[-1] == ')':        
            station = ''.join(station.split('(')[:-1])
        if station[-1] == '역':
            station = station[:-1]
        station_list.append(station)
        
    stations['역사명']=station_list
    return stations

# 띄어쓰기 제거
def spaceClear(stations):
    station_list = []
    for station in stations['영문역사명']:
        station_list.append(station.replace(" ",""))

    stations['영문역사명']=station_list
    return stations

# 2열 데이터 프레임을 딕셔너리로
def df2dict(df):
    if df.shape[1] != 2 :
        return print('only 2 columns')
    
    df_dict = {}
    for key, value in zip(df.iloc[:, 0], df.iloc[:, 1]):
        df_dict[key] = value
        
    return df_dict

# %% [markdown]
# # 지리적정보 stationDf

# %%
stations = pd.read_csv('data/input/전국도시철도역사정보표준데이터.csv')
stations
# Out:
#        역번호     역사명   노선번호          노선명               영문역사명   한자역사명 환승역구분  \
# 0     3122   부평삼거리  S2801    인천지하철 1호선    Bupyeongsamgeori   富平三거리   일반역
# 1     3123   간석오거리  S2801    인천지하철 1호선       Ganseogogeori   間石五거리   일반역
# ...    ...     ...    ...          ...                 ...     ...   ...
# 1013  4137    둔촌오륜  S1109  서울 도시철도 9호선       Dunchon Oryun    遁村五輪   일반역
# 1014  4138  중앙보훈병원  S1109  서울 도시철도 9호선  VHS Medical Center  中央報?病院   일반역
#
#      환승노선번호 환승노선명        역위도         역경도   운영기관명             역사도로명주소  \
# 0         -     -  37.478267  126.710494  인천교통공사   인천광역시 부평구 경인로 765
# 1         -     -  37.466921  126.707861  인천교통공사   인천광역시 남동구 경인로 674
# ...     ...   ...        ...         ...     ...                 ...
# 1013    NaN   NaN  37.517975  127.140170  서울교통공사  서울특별시 송파구 강동대로 327
# 1014    NaN   NaN  37.529614  127.142757  서울교통공사   서울특별시 강동구 명일로 117
#
#             역사전화번호     데이터기준일자   제공기관코드   제공기관명
# 0     032-516-3122  2020-11-30  B551894  인천교통공사
# 1     032-434-3123  2020-11-30  B551894  인천교통공사
# ...            ...         ...      ...     ...
# 1013  02-2656-0937  2021-04-09  B553766  서울교통공사
# 1014  02-2656-0938  2021-04-09  B553766  서울교통공사
#
# [1015 rows x 17 columns]

# %%
stationNameClear(stations)
spaceClear(stations)
# Out:
#        역번호     역사명   노선번호          노선명             영문역사명   한자역사명 환승역구분 환승노선번호  \
# 0     3122   부평삼거리  S2801    인천지하철 1호선  Bupyeongsamgeori   富平三거리   일반역      -
# 1     3123   간석오거리  S2801    인천지하철 1호선     Ganseogogeori   間石五거리   일반역      -
# ...    ...     ...    ...          ...               ...     ...   ...    ...
# 1013  4137    둔촌오륜  S1109  서울 도시철도 9호선      DunchonOryun    遁村五輪   일반역    NaN
# 1014  4138  중앙보훈병원  S1109  서울 도시철도 9호선  VHSMedicalCenter  中央報?病院   일반역    NaN
#
#      환승노선명        역위도         역경도   운영기관명             역사도로명주소        역사전화번호  \
# 0        -  37.478267  126.710494  인천교통공사   인천광역시 부평구 경인로 765  032-516-3122
# 1        -  37.466921  126.707861  인천교통공사   인천광역시 남동구 경인로 674  032-434-3123
# ...    ...        ...         ...     ...                 ...           ...
# 1013   NaN  37.517975  127.140170  서울교통공사  서울특별시 송파구 강동대로 327  02-2656-0937
# 1014   NaN  37.529614  127.142757  서울교통공사   서울특별시 강동구 명일로 117  02-2656-0938
#
#          데이터기준일자   제공기관코드   제공기관명
# 0     2020-11-30  B551894  인천교통공사
# 1     2020-11-30  B551894  인천교통공사
# ...          ...      ...     ...
# 1013  2021-04-09  B553766  서울교통공사
# 1014  2021-04-09  B553766  서울교통공사
#
# [1015 rows x 17 columns]

# %%
stationDf=stations[['역사명','영문역사명','역위도','역경도']]
stationDf.rename(columns={'역사명':'kor_name','영문역사명':'eng_name','역위도':'latitude','역경도':'longitude'},inplace=True)
stationDf
# Out:
# C:\Users\82104\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      kor_name          eng_name   latitude   longitude
# 0       부평삼거리  Bupyeongsamgeori  37.478267  126.710494
# 1       간석오거리     Ganseogogeori  37.466921  126.707861
# ...       ...               ...        ...         ...
# 1013     둔촌오륜      DunchonOryun  37.517975  127.140170
# 1014   중앙보훈병원  VHSMedicalCenter  37.529614  127.142757
#
# [1015 rows x 4 columns]

# %%
stationName_ix = stationDf['eng_name'].values
stationName_ix
# Out:
# array(['Bupyeongsamgeori', 'Ganseogogeori', 'IncheonCityHall', ...,
#        'OlympicPark', 'DunchonOryun', 'VHSMedicalCenter'], dtype=object)

# %%
metroKorEngDict=df2dict(stationDf[['kor_name','eng_name']])
# md
# stationDf['to_eng']=stationDf['to'].map(md)
# stationDf

# %% [markdown]
# # 노선정보 route

# %%
subway = pd.read_csv('data/input/subway.csv')
subway
# Out:
#     from   to line
# 0    소요산  동두천    1
# 1    동두천   보산    1
# ..   ...  ...  ...
# 694   초지   원곡  서해선
# 695   원곡   원시  서해선
#
# [696 rows x 3 columns]

# %%
subway['from'] = subway['from'].map(metroKorEngDict)
subway['to'] = subway['to'].map(metroKorEngDict)
subway.dropna(inplace=True)
subway
# Out:
#                      from            to  line
# 0                 Soyosan   Dongducheon     1
# 1             Dongducheon         Bosan     1
# ..                    ...           ...   ...
# 683  SungshinWomen`sUniv.         Bomun  우이신설
# 684                 Bomun  Sinseol-dong  우이신설
#
# [609 rows x 3 columns]

# %%
subway = subway[(subway['from'].isin(stationName_ix)) & (subway['to'].isin(stationName_ix))]
subwayDf = subway[['from','to']]
subwayDf
# Out:
#                      from            to
# 0                 Soyosan   Dongducheon
# 1             Dongducheon         Bosan
# ..                    ...           ...
# 683  SungshinWomen`sUniv.         Bomun
# 684                 Bomun  Sinseol-dong
#
# [609 rows x 2 columns]

# %%
subwayDf =  pd.DataFrame(subwayDf.groupby(['from', 'to']).size().reset_index(name='counts'))
subwayDf
# Out:
#         from            to  counts
# 0    Achasan     Gwangnaru       1
# 1     Aeogae  Chungjeongno       1
# ..       ...           ...     ...
# 602  Yongsan         Ichon       1
# 603  Yongsan    Noryangjin       1
#
# [604 rows x 3 columns]

# %% [markdown]
# # counts

# %%
counts = subwayDf['from'].append(subwayDf.loc[subwayDf['from'] != subwayDf['to'], 'to']).value_counts()
counts = pd.DataFrame({'eng_name': counts.index, 'total': counts})
counts
# Out:
#               eng_name  total
# Wangsimni    Wangsimni      7
# Gongdeok      Gongdeok      6
# ...                ...    ...
# Amsa              Amsa      1
# Seodongtan  Seodongtan      1
#
# [541 rows x 2 columns]

# %% [markdown]
# # pos_data

# %%
pos_data = counts.merge(stationDf, on = 'eng_name')
pos_data
# Out:
#        eng_name  total kor_name   latitude   longitude
# 0     Wangsimni      7      왕십리  37.561525  127.037508
# 1     Wangsimni      7      왕십리  37.561128  127.035505
# ..          ...    ...      ...        ...         ...
# 652        Amsa      1       암사  37.549975  127.127418
# 653  Seodongtan      1      서동탄  37.195675  127.051893
#
# [654 rows x 5 columns]

# %% [markdown]
# # Graph

# %%
graph = nx.from_pandas_edgelist(
    subwayDf,
    source = 'from',
    target = 'to',
    edge_attr = 'counts',
    create_using = nx.DiGraph())

plt.figure(figsize = (20,19))
nx.draw_networkx(graph)

# %%
plt.figure(figsize=(10,10))
m = Basemap(
    projection='merc',
    llcrnrlon=122,
    llcrnrlat=33,
    urcrnrlon=132,
    urcrnrlat=40,
    lat_ts=0,
    resolution='l',
    suppress_ticks=True)

# plt.figure(figsize = (20,25))
# m = Basemap(
#     projection='merc',
#     llcrnrlon=125,
#     llcrnrlat=33,
#     urcrnrlon=130,
#     urcrnrlat=39,
#     lat_ts=0,
#     resolution='l',
#     suppress_ticks=True)
# m.drawcountries(linewidth = 2)
# m.drawstates(linewidth = 1)
# m.drawcoastlines(linewidth=2)

# import long lat as m attribute
mx, my = m(pos_data['longitude'].values, pos_data['latitude'].values)
pos = {}
for count, elem in enumerate (pos_data['eng_name']):
    pos[elem] = (mx[count], my[count])

# # print(pos)
# #draw nodes and edges and over aly on basemap
# # nodes
nx.draw_networkx_nodes(
    G = graph,
    pos = pos,
    nodelist = graph.nodes(),
    node_color = 'r',
    alpha = 0.8,
    node_size = [counts['total'][s]*5 for s in graph.nodes()])

# edges
nx.draw_networkx_edges(
    G = graph,
    pos = pos,
    edge_color='g',
    width = subwayDf['counts']*1,
    alpha=0.5,
    arrows = False)

m.drawcoastlines()
m.drawcountries()
m.drawmapboundary()

# lat/lon setting
parallels = np.arange(30.,50.,1.)
m.drawparallels(parallels,labels=[True,False,False,False])
meridians = np.arange(120.,150.,2.)
m.drawmeridians(meridians,labels=[True,False,False,True])
plt.show()
# m.drawcountries(linewidth = 2)
# m.drawstates(linewidth = 0.2)
# m.drawcoastlines(linewidth=2)
# m.fillcontinents(alpha = 0.3)
# plt.tight_layout()
# # plt.savefig("output/images/networkx_basemap2.png", format = "png", dpi = 300)
# plt.show()

# %%
plt.figure(figsize = (10,10))
m = Basemap(
    projection='merc',
    llcrnrlon=126,
    llcrnrlat=36,
    urcrnrlon=129,
    urcrnrlat=38.5,
    lat_ts=0,
    resolution='l',
    suppress_ticks=True)
mx, my = m(pos_data['longitude'].values, pos_data['latitude'].values)
pos = {}
for count, elem in enumerate (pos_data['eng_name']):
    pos[elem] = (mx[count], my[count])
# 100이하 노드
nx.draw_networkx_nodes(
    G = graph,
    pos = pos,
    nodelist = [x for x in graph.nodes() if counts['total'][x] < 5],
    node_color = 'b',
    alpha = 0.8,
    node_size = [counts['total'][x]*4  for x in graph.nodes() if counts['total'][x] < 5])
# 100이상 nodes
nx.draw_networkx_nodes(
    G = graph,
    pos = pos,
    nodelist = [x for x in graph.nodes() if counts['total'][x] >= 5],
    node_color = 'r',
    alpha = 1,
    node_size = [counts['total'][x]*10  for x in graph.nodes() if counts['total'][x] >= 5])
# 100이상 labels
# nx.draw_networkx_labels(
#     G = graph,
#     pos = pos,
#     font_size=10,
#     labels = {x:x for x in graph.nodes() if counts['total'][x] >= 6})
# edges
nx.draw_networkx_edges(
    G = graph,
    pos = pos,
    edge_color = 'g',
    width = subwayDf['counts']*0.75, 
    alpha=0.8,
    arrows = False)

m.drawcountries(linewidth = 0.8)
m.drawstates(linewidth = 0.2)
m.drawcoastlines(linewidth = 0.8)
m.fillcontinents(alpha = 0.3)
# lat/lon setting
parallels = np.arange(30.,50.,1.)
m.drawparallels(parallels,labels=[True,False,False,False])
meridians = np.arange(120.,150.,2.)
m.drawmeridians(meridians,labels=[True,False,False,True])
plt.show()
# line1 = mlines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="red")
# line2 = mlines.Line2D(range(1), range(1), color="white", marker='o',markerfacecolor="blue")
# line3 = mlines.Line2D(range(1), range(1), color="green", marker='',markerfacecolor="green")
# plt.legend((line1, line2, line3), ('Large > 5 routes', 'Smaller airports', 'routes'), loc=4, fontsize = 'xx-large')
# m.bluemarble()
# m.etopo()
